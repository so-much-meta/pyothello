# %%
from pyothello.learn import Net1, NeuralEvaluator, Trainer
trainer = Trainer()
trainer.play_training_game()
trainer.learn_from_game()

# %%
# %%timeit
trainer.play_training_game()
trainer.learn_from_game()
# Out:
# 598 ms ± 41.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
trainer.play_sample_game()
# Out:
#
#
#
#    O#
#    #O
#
#
#
# NEXT: BLACK
#
# Chose (5, 4) with eval 0.45718514919281006
# Color BLACK: (5, 4)
#
#
#
#    O#
#    ##
#     #
#
#
# NEXT: WHITE
#
# Chose (3, 5) with eval 0.5386786758899689
# Color WHITE: (3, 5)
#
#
#
#    OOO
#    ##
#     #
#
#
# NEXT: BLACK
#
# Chose (2, 6) with eval 0.4572882056236267
# Color BLACK: (2, 6)
#
#
#       #
#    OO#
#    ##
#     #
#
#
# NEXT: WHITE
#
# Chose (6, 4) with eval 0.5406054854393005
# Color WHITE: (6, 4)
#
#
#       #
#    OO#
#    #O
#     O
#     O
#
# NEXT: BLACK
#
# Chose (2, 5) with eval 0.45745572447776794
# Color BLACK: (2, 5)
#
#
#      ##
#    O##
#    #O
#     O
#     O
#
# NEXT: WHITE
#
# Chose (3, 6) with eval 0.5430721938610077
# Color WHITE: (3, 6)
#
#
#      ##
#    OOOO
#    #O
#     O
#     O
#
# NEXT: BLACK
#
# Chose (4, 5) with eval 0.4567105770111084
# Color BLACK: (4, 5)
#
#
#      ##
#    OO#O
#    ###
#     O
#     O
#
# NEXT: WHITE
#
# Chose (5, 6) with eval 0.5422979891300201
# Color WHITE: (5, 6)
#
#
#      ##
#    OO#O
#    ##O
#     O O
#     O
#
# NEXT: BLACK
#
# Chose (7, 4) with eval 0.45869335532188416
# Color BLACK: (7, 4)
#
#
#      ##
#    OO#O
#    ##O
#     # O
#     #
#     #
# NEXT: WHITE
#
# Chose (1, 5) with eval 0.5423965454101562
# Color WHITE: (1, 5)
#
#      O
#      O#
#    OOOO
#    ##O
#     # O
#     #
#     #
# NEXT: BLACK
#
# Chose (1, 6) with eval 0.45726585388183594
# Color BLACK: (1, 6)
#
#      O#
#      ##
#    O#OO
#    ##O
#     # O
#     #
#     #
# NEXT: WHITE
#
# Chose (6, 3) with eval 0.5436123311519623
# Color WHITE: (6, 3)
#
#      O#
#      ##
#    O#OO
#    ##O
#     O O
#    O#
#     #
# NEXT: BLACK
#
# Chose (6, 7) with eval 0.4572506546974182
# Color BLACK: (6, 7)
#
#      O#
#      ##
#    O#OO
#    ###
#     O #
#    O#  #
#     #
# NEXT: WHITE
#
# Chose (5, 5) with eval 0.5423460602760315
# Color WHITE: (5, 5)
#
#      O#
#      ##
#    O#OO
#    #OO
#     OO#
#    O#  #
#     #
# NEXT: BLACK
#
# Chose (6, 5) with eval 0.4624274671077728
# Color BLACK: (6, 5)
#
#      O#
#      ##
#    O##O
#    #O#
#     ###
#    O## #
#     #
# NEXT: WHITE
#
# Chose (6, 6) with eval 0.5392625629901886
# Color WHITE: (6, 6)
#
#      O#
#      ##
#    O##O
#    #O#
#     #O#
#    OOOO#
#     #
# NEXT: BLACK
#
# Chose (6, 2) with eval 0.4625612199306488
# Color BLACK: (6, 2)
#
#      O#
#      ##
#    O##O
#    #O#
#     #O#
#   ######
#     #
# NEXT: WHITE
#
# Chose (7, 2) with eval 0.5403710901737213
# Color WHITE: (7, 2)
#
#      O#
#      ##
#    O##O
#    #OO
#     OO#
#   #O####
#   O #
# NEXT: BLACK
#
# Chose (5, 3) with eval 0.46198973059654236
# Color BLACK: (5, 3)
#
#      O#
#      ##
#    O##O
#    ##O
#    ####
#   #O####
#   O #
# NEXT: WHITE
#
# Chose (7, 7) with eval 0.5387334525585175
# Color WHITE: (7, 7)
#
#      O#
#      ##
#    O##O
#    #OO
#    ##O#
#   #O##O#
#   O #  O
# NEXT: BLACK
#
# Chose (7, 3) with eval 0.46107161045074463
# Color BLACK: (7, 3)
#
#      O#
#      ##
#    O##O
#    #OO
#    ##O#
#   ####O#
#   O##  O
# NEXT: WHITE
#
# Chose (5, 2) with eval 0.5404525697231293
# Color WHITE: (5, 2)
#
#      O#
#      ##
#    O##O
#    #OO
#   OOOO#
#   O###O#
#   O##  O
# NEXT: BLACK
#
# Chose (5, 1) with eval 0.4622691571712494
# Color BLACK: (5, 1)
#
#      O#
#      ##
#    O##O
#    #OO
#  ######
#   ####O#
#   O##  O
# NEXT: WHITE
#
# Chose (6, 1) with eval 0.5406119227409363
# Color WHITE: (6, 1)
#
#      O#
#      ##
#    O##O
#    #OO
#  ######
#  OOOOOO#
#   O##  O
# NEXT: BLACK
#
# Chose (0, 5) with eval 0.46278849244117737
# Color BLACK: (0, 5)
#      #
#      ##
#      ##
#    O##O
#    #OO
#  ######
#  OOOOOO#
#   O##  O
# NEXT: WHITE
#
# Chose (4, 6) with eval 0.5404812693595886
# Color WHITE: (4, 6)
#      #
#      ##
#      ##
#    O##O
#    #OOO
#  ####OO
#  OOOOOO#
#   O##  O
# NEXT: BLACK
#
# Chose (5, 7) with eval 0.4627661406993866
# Color BLACK: (5, 7)
#      #
#      ##
#      ##
#    O##O
#    #OO#
#  #######
#  OOOOOO#
#   O##  O
# NEXT: WHITE
#
# Chose (3, 2) with eval 0.5401293933391571
# Color WHITE: (3, 2)
#      #
#      ##
#      ##
#   OO##O
#    OOO#
#  ###O###
#  OOOOOO#
#   O##  O
# NEXT: BLACK
#
# Chose (7, 5) with eval 0.46238973736763
# Color BLACK: (7, 5)
#      #
#      ##
#      ##
#   OO##O
#    OOO#
#  ###O###
#  OOO####
#   O### O
# NEXT: WHITE
#
# Chose (1, 4) with eval 0.5392952561378479
# Color WHITE: (1, 4)
#      #
#     O##
#      O#
#   OO##O
#    OOO#
#  ###O###
#  OOO####
#   O### O
# NEXT: BLACK
#
# Chose (2, 1) with eval 0.4639539122581482
# Color BLACK: (2, 1)
#      #
#     O##
#  #   O#
#   #O##O
#    #OO#
#  #######
#  OOO####
#   O### O
# NEXT: WHITE
#
# Chose (1, 7) with eval 0.5383945107460022
# Color WHITE: (1, 7)
#      #
#     OOOO
#  #   OO
#   #O#OO
#    #OO#
#  #######
#  OOO####
#   O### O
# NEXT: BLACK
#
# Chose (0, 7) with eval 0.46164318919181824
# Color BLACK: (0, 7)
#      # #
#     OO#O
#  #   #O
#   #O#OO
#    #OO#
#  #######
#  OOO####
#   O### O
# NEXT: WHITE
#
# Chose (4, 7) with eval 0.5399623513221741
# Color WHITE: (4, 7)
#      # #
#     OO#O
#  #   #O
#   #O#OO
#    #OOOO
#  ######O
#  OOO###O
#   O### O
# NEXT: BLACK
#
# Chose (1, 3) with eval 0.4620338976383209
# Color BLACK: (1, 3)
#      # #
#    ####O
#  #   #O
#   #O#OO
#    #OOOO
#  ######O
#  OOO###O
#   O### O
# NEXT: WHITE
#
# Chose (1, 2) with eval 0.5411987602710724
# Color WHITE: (1, 2)
#      # #
#   OOOOOO
#  #   #O
#   #O#OO
#    #OOOO
#  ######O
#  OOO###O
#   O### O
# NEXT: BLACK
#
# Chose (2, 7) with eval 0.4599473476409912
# Color BLACK: (2, 7)
#      # #
#   OOOO##
#  #   ###
#   #O#O#
#    #O#OO
#  ######O
#  OOO###O
#   O### O
# NEXT: WHITE
#
# Chose (5, 0) with eval 0.5433633625507355
# Color WHITE: (5, 0)
#      # #
#   OOOO##
#  #   ###
#   #O#O#
#    #O#OO
# OOOOOOOO
#  OOO###O
#   O### O
# NEXT: BLACK
#
# Chose (1, 1) with eval 0.459582656621933
# Color BLACK: (1, 1)
#      # #
#  #######
#  #   ###
#   #O#O#
#    #O#OO
# OOOOOOOO
#  OOO###O
#   O### O
# NEXT: WHITE
#
# Chose (1, 0) with eval 0.5420605540275574
# Color WHITE: (1, 0)
#      # #
# O#######
#  O   ###
#   OO#O#
#    OO#OO
# OOOOOOOO
#  OOO###O
#   O### O
# NEXT: BLACK
#
# Chose (3, 1) with eval 0.46051037311553955
# Color BLACK: (3, 1)
#      # #
# O#######
#  #   ###
#  ####O#
#    OO#OO
# OOOOOOOO
#  OOO###O
#   O### O
# NEXT: WHITE
#
# Chose (3, 0) with eval 0.5430556535720825
# Color WHITE: (3, 0)
#      # #
# O#######
#  #   ###
# OOOOOO#
#    OO#OO
# OOOOOOOO
#  OOO###O
#   O### O
# NEXT: BLACK
#
# Chose (2, 4) with eval 0.459557443857193
# Color BLACK: (2, 4)
#      # #
# O#######
#  #  ####
# OOOO#O#
#    O##OO
# OOOO#OOO
#  OOO###O
#   O### O
# NEXT: WHITE
#
# Chose (0, 6) with eval 0.541090339422226
# Color WHITE: (0, 6)
#      #O#
# O####OO#
#  #  O#O#
# OOOO#OO
#    O##OO
# OOOO#OOO
#  OOO###O
#   O### O
# NEXT: BLACK
#
# Chose (3, 7) with eval 0.46313998103141785
# Color BLACK: (3, 7)
#      #O#
# O####OO#
#  #  O#O#
# OOOO####
#    O###O
# OOOO##OO
#  OOO###O
#   O### O
# NEXT: WHITE
#
# Chose (0, 1) with eval 0.539682537317276
# Color WHITE: (0, 1)
#  O   #O#
# OO###OO#
#  O  O#O#
# OOOO####
#    O###O
# OOOO##OO
#  OOO###O
#   O### O
# NEXT: BLACK
#
# Chose (4, 1) with eval 0.4601059854030609
# Color BLACK: (4, 1)
#  O   #O#
# OO###OO#
#  O  O#O#
# OOOO####
#  # O###O
# OO#O##OO
#  OO####O
#   O### O
# NEXT: WHITE
#
# Chose (2, 3) with eval 0.5393482744693756
# Color WHITE: (2, 3)
#  O   #O#
# OOO##OO#
#  O OO#O#
# OOOOO###
#  # O#O#O
# OO#O##OO
#  OO####O
#   O### O
# NEXT: BLACK
#
# Chose (0, 4) with eval 0.45820748805999756
# Color BLACK: (0, 4)
#  O  ##O#
# OOO###O#
#  O OO###
# OOOOO###
#  # O#O#O
# OO#O##OO
#  OO####O
#   O### O
# NEXT: WHITE
#
# Chose (0, 3) with eval 0.5402562320232391
# Color WHITE: (0, 3)
#  O OOOO#
# OOOOO#O#
#  O OOO##
# OOOOO#O#
#  # O#O#O
# OO#O##OO
#  OO####O
#   O### O
# NEXT: BLACK
#
# Chose (0, 2) with eval 0.4595597982406616
# Color BLACK: (0, 2)
#  O######
# OOO#O#O#
#  O O#O##
# OOOOO#O#
#  # O#O#O
# OO#O##OO
#  OO####O
#   O### O
# NEXT: WHITE
#
# Chose (4, 2) with eval 0.5382627248764038
# Color WHITE: (4, 2)
#  O######
# OOO#O#O#
#  O O#O##
# OOOOO#O#
#  #OO#O#O
# OOOO##OO
#  OO####O
#   O### O
# NEXT: BLACK
#
# Chose (7, 0) with eval 0.46241700649261475
# Color BLACK: (7, 0)
#  O######
# OOO#O###
#  O O####
# OOOO##O#
#  #O##O#O
# OO#O##OO
#  #O####O
# # O### O
# NEXT: WHITE
#
# Chose (7, 6) with eval 0.5373083055019379
# Color WHITE: (7, 6)
#  O######
# OOO#O###
#  O O####
# OOOO##O#
#  #OO#O#O
# OO#OO#OO
#  #O##OOO
# # OOOOOO
# NEXT: BLACK
#
# Chose (2, 0) with eval 0.4621918201446533
# Color BLACK: (2, 0)
#  O######
# O#O#O###
# #O O####
# O#OO##O#
#  ##O#O#O
# OO##O#OO
#  #O##OOO
# # OOOOOO
# NEXT: WHITE
#
# Chose (4, 0) with eval 0.5367163717746735
# Color WHITE: (4, 0)
#  O######
# O#O#O###
# #O O####
# O#OO##O#
# OOOO#O#O
# OO##O#OO
#  #O##OOO
# # OOOOOO
# NEXT: BLACK
#
# Chose (2, 2) with eval 0.4652048349380493
# Color BLACK: (2, 2)
#  O######
# O###O###
# ########
# O#####O#
# OO#O#O#O
# OO##O#OO
#  #O##OOO
# # OOOOOO
# NEXT: WHITE
#
# Chose (0, 0) with eval 0.535201907157898
# Color WHITE: (0, 0)
# OO######
# OO##O###
# ##O#####
# O##O##O#
# OO#OOO#O
# OO##OOOO
#  #O##OOO
# # OOOOOO
# NEXT: BLACK
#
# Chose (6, 0) with eval 0.4621638357639313
# Color BLACK: (6, 0)
# OO######
# OO##O###
# ##O#####
# ###O##O#
# #O#OOO#O
# ####OOOO
# ##O##OOO
# # OOOOOO
# NEXT: WHITE
#
# Chose (7, 1) with eval 0.5350500643253326
# Color WHITE: (7, 1)
# OO######
# OO##O###
# ##O#####
# ###O##O#
# #O#OOO#O
# #O##OOOO
# #OO##OOO
# #OOOOOOO
# NEXT: BLACK
#
# Chose PASS with eval 0.45303553342819214
# Color BLACK: PASS
# OO######
# OO##O###
# ##O#####
# ###O##O#
# #O#OOO#O
# #O##OOOO
# #OO##OOO
# #OOOOOOO
# NEXT: WHITE
#
# Color WHITE: PASS
# OO######
# OO##O###
# ##O#####
# ###O##O#
# #O#OOO#O
# #O##OOOO
# #OO##OOO
# #OOOOOOO
# WINNER: BLACK
